# %%
import nest_asyncio
nest_asyncio.apply()
from app.agent import tutor_session
import asyncio

async def test_agent():
    print('Sending question: \"What is Mars?\"')
    response = await tutor_session('What is Mars?', 'test_student_123')
    print('Response:', response)

await test_agent()
# Out:
# Sending question: "What is Mars?"
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain_google_genai\chat_models.py:3088, in ChatGoogleGenerativeAI._agenerate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3086 try:
#    3087     response: GenerateContentResponse = (
# -> 3088         await self.client.aio.models.generate_content(
#    3089             **request,
#    3090         )
#    3091     )
#    3092 except ClientError as e:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\google\genai\models.py:7018, in AsyncModels.generate_content(self, model, contents, config)
#    7011     logger.warning(
#    7012         'Tools at indices [%s] are not compatible with automatic function '
# ...
